# %% [markdown]
# # Dongle Testing

# %%
import sys
import importlib.util
from pathlib import Path

file_path = Path('tests/test_query/test_distance_preservation.py').resolve()
module_name = file_path.stem

spec = importlib.util.spec_from_file_location(module_name, file_path)
module = importlib.util.module_from_spec(spec)
sys.modules[module_name] = module
spec.loader.exec_module(module)

print(module.test_id_spider_simp())
# Out:
# Constructing signatures of g1...
# Expanding 6 gadgets!
# Firing X onto (0, 1) for gadget #0 (from web edge: (0, 1))
# Firing X onto (0, 2) for gadget #0 (from web edge: (0, 2))
# Firing X onto (0, 1) for gadget #2 (from web edge: (0, 1))
# Firing X onto (0, 2) for gadget #2 (from web edge: (0, 2))
# Firing Z onto (0, 1) for gadget #4 (from web edge: (0, 1))
# Firing Z onto (0, 2) for gadget #4 (from web edge: (0, 2))
# Firing Z onto (0, 1) for gadget #5 (from web edge: (0, 1))
# Firing Z onto (0, 2) for gadget #5 (from web edge: (0, 2))
# Reducing 2 targets of type X from gadget #0 on edge (0, 1)!
# Reducing 2 targets of type X from gadget #2 on edge (0, 1)!
# Reducing 2 targets of type Z from gadget #4 on edge (0, 2)!
# Reducing 2 targets of type Z from gadget #5 on edge (0, 2)!
# Constructing signatures of g2...
# Expanding 3 gadgets!
# Checking if g1 -> g2 is distance non-decreasing...
# Starting weight iteration until 2!
# Starting weight: 1...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 13
#      10 sys.modules[module_name] = module
#      11 spec.loader.exec_module(module)
# ---> 13 print(module.test_id_spider_simp())
#
# File ~/dev/oxford/msc-thesis/tests/test_query/test_distance_preservation.py:24, in test_id_spider_simp()
#      21 g2 = GraphS()
#      22 g2.add_edges([(g2.add_vertex(zx.VertexType.BOUNDARY), g2.add_vertex(zx.VertexType.BOUNDARY))])
# ---> 24 assert is_distance_preserving(g1, g2, quiet=False)
#
# File ~/dev/oxford/msc-thesis/src/faultgadget/query/distance_preserving.py:149, in is_distance_preserving(g1, g2, quiet)
#     146 expand_all_gadgets(gg2, quiet=quiet)
#     148 if not quiet: print("Checking if g1 -> g2 is distance non-decreasing...")
# --> 149 if not check_distance_non_decreasing(gg1, gg2, quiet=quiet):
#     150     return False
#     152 if not quiet: print("Checking if g2 -> g1 is distance non-decreasing...")
#
# File ~/dev/oxford/msc-thesis/src/faultgadget/query/distance_preserving.py:98, in check_distance_non_decreasing(g1, g2, quiet)
#      96 if _sig_detectable(combined_sig, g1_num_sinks):
#      97     continue # Detectable g1 signatures will never be queried, so save space here
# ---> 98 sig_int = _sig_wo_sinks_to_int(combined_sig, g1_num_sinks)
#      99 if sig_int not in g1_lookup:
#     100     g1_lookup[sig_int] = max_weight
#
# File ~/dev/oxford/msc-thesis/src/faultgadget/query/distance_preserving.py:64, in _sig_wo_sinks_to_int(sig, sinks)
#      62 def _sig_wo_sinks_to_int(sig: GF2, sinks: int) -> int:
#      63     reduced_sig = sig[:-(sinks * 2)] if sinks > 0 else sig
# ---> 64     return _sig_to_int(reduced_sig)
#
# File ~/dev/oxford/msc-thesis/src/faultgadget/query/distance_preserving.py:56, in _sig_to_int(sig)
#      52         signature_normal_forms.append(np_sig)
#      54     return np.unique(GF2(signature_normal_forms), axis=0).view(GF2)
# ---> 56 def _sig_to_int(sig: GF2) -> int:
#      57     out = 0
#      58     for bit in sig.tolist():
#
# File ~/.local/share/JetBrains/Toolbox/apps/pycharm-professional/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_trace_dispatch_regular.py:366, in ThreadTracer.__call__(self, frame, event, arg)
#     363         self._args = args
#     364 # ENDIF
# --> 366     def __call__(self, frame, event, arg):
#     367         ''' This is the callback used when we enter some context in the debugger.
#     368
#     369         We also decorate the thread we are in with info about the debugging.
#    (...)    377             This is the global debugger (this method should actually be added as a method to it).
#     378         '''
#     379         # IFDEF CYTHON
#     380         # cdef str filename;
#     381         # cdef str base;
#    (...)    388         # ENDIF
#     389         # print('ENTER: trace_dispatch', frame.f_code.co_filename, frame.f_lineno, event, frame.f_code.co_name)
#
# KeyboardInterrupt:
