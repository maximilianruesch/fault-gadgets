# %% [markdown]
# # Sampling fault signatures:

# %%
import time
import pyzx as zx
from faultgadget.query.sampling import sample_signatures

g = zx.generate.cnots(3, 4, backend='simple')
start_time = time.time()
for i, sig in enumerate(sample_signatures(g, shots=10000000)):
    if i == 0:
        print(f"Startup time: {time.time() - start_time} seconds!")
        start_time = time.time()

    if i % 100000 == 0:
        print(f"Sampling at {i / (time.time() - start_time)} Hz...")
# Out:
# Startup time: 0.6211304664611816 seconds!
# Sampling at 0.0 Hz...
# Sampling at 26536.56215726487 Hz...
# Sampling at 32491.545180154262 Hz...
# Sampling at 40656.68025463803 Hz...
# Sampling at 47058.18863507626 Hz...
# Sampling at 52369.41570106578 Hz...
# Sampling at 56511.334187903136 Hz...
# Sampling at 60049.91852697374 Hz...
# Sampling at 63005.63346181342 Hz...
# Sampling at 65391.51427046524 Hz...
# Sampling at 67444.30174181661 Hz...
# Sampling at 69148.95946482159 Hz...
# Sampling at 70609.87581387913 Hz...
# Sampling at 71842.89710407096 Hz...
# Sampling at 73092.07518687099 Hz...
# Sampling at 74285.38793071437 Hz...
# Sampling at 75327.08599199925 Hz...
# Sampling at 76246.71365066283 Hz...
# Sampling at 77089.83500650425 Hz...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 7
#       5 g = zx.generate.cnots(3, 4, backend='simple')
# ...
